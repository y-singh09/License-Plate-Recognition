# %%
# !apt-get install tesseract-ocr
# !pip install pytesseract
# !pip install python-bidi
# !pip install easyocr
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# ...
# WARNING: There was an error checking the latest version of pip.
# ...
# WARNING: There was an error checking the latest version of pip.
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from IPython.display import Image
import json

# %%
Image(r"C:\Users\Rana Yuvi\OneDrive\Desktop\CGIP_miniproject\pics\WhatsApp Image 2024-07-26 at 01.20.18_1db0f51b.jpg")

# %%
reader = easyocr.Reader(['en'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
output = reader.readtext(r'C:\Users\Rana Yuvi\OneDrive\Desktop\CGIP_miniproject\pics\WhatsApp Image 2024-07-26 at 01.20.18_1db0f51b.jpg')

# %%
output
a,b=output

# %%
key=output[1][1]

# %%
import json
from PIL import Image
import pytesseract
from IPython.display import display



vehicle_data = {
    "7 /:BR 05 E5000": {
        "Name": "Arjun Kumar",
        "Address": "10, MG Road, Bangalore, Karnataka",
        "State": "Karnataka",
        "Vehicle": "Honda City"
    },
    'MN03 T 2532': {
       
        "Name": "Rajesh Gupta",
        "Address": "45, Park Street, Kolkata, West Bengal",
        "State": "West Bengal",
        "Vehicle": "Maruti Swift", "img":r'C:\Users\Rana Yuvi\OneDrive\Desktop\CGIP_miniproject\pics\WhatsApp Image 2024-07-26 at 01.20.18_6e942c19.jpg'
    },
    "22BH6517A": {
        "Name": "Sneha Sharma",
        "Address": "32, Gandhi Nagar, Mumbai, Maharashtra",
        "State": "Maharashtra",
        "Vehicle": "Hyundai i20"
    },
    "BR19G8869": {
        "Name": "Anil Singh",
        "Address": "15, Patna Junction, Patna, Bihar",
        "State": "Bihar",
        "Vehicle": "Tata Nexon"
    },
    "GJ23AU0819": {
        "Name": "Mehul Patel",
        "Address": "22, Ashram Road, Ahmedabad, Gujarat",
        "State": "Gujarat",
        "Vehicle": "Mahindra Thar"
    },
    "NO7CM4 123": {
        "Name": "Priya Iyer",
        "Address": "78, Anna Salai, Chennai, Tamil Nadu",
        "State": "Tamil Nadu",
        "Vehicle": "Ford EcoSport"
    },
    "BR05E5000": {
        "Name": "Manoj Kumar",
        "Address": "98, Rajendra Nagar, Patna, Bihar",
        "State": "Bihar",
        "Vehicle": "Renault Duster"
    },
    "MH43PR2356": {
        "Name": "Aishwarya Joshi",
        "Address": "54, Bandra West, Mumbai, Maharashtra",
        "State": "Maharashtra",
        "Vehicle": "BMW X5"
    },
    "e2BR 19 G 8869": {
        "Name": "Rakesh Singh",
        "Address": "12, Thangal Bazar, Imphal, Manipur",
        "State": "Manipur",
        "Vehicle": "Suzuki Baleno"
    },
    "TNO7CML123": {
        "Name": "Suresh Reddy",
        "Address": "5, Banjara Hills, Hyderabad, Telangana",
        "State": "Telangana",
        "Vehicle": "Toyota Fortuner"
    },
    "TNO7CM4 123": {
        "Name": "Kavya Nair",
        "Address": "34, Koramangala, Bangalore, Karnataka",
        "State": "Karnataka",
        "Vehicle": "Audi Q7"
    },
    "GA03MF4477": {
        "Name": "John D'Souza",
        "Address": "77, Panjim, Goa",
        "State": "Goa",
        "Vehicle": "Jeep Compass"
    },
    "TNO7CM4123": {
        "Name": "Neha Verma",
        "Address": "20, Mall Road, Shimla, Himachal Pradesh",
        "State": "Himachal Pradesh",
        "Vehicle": "Maruti Alto"
    }
}
def load_image(image_path):
    try:
        return Image.open(image_path)
    except Exception as e:
        print(f"Error loading image from {image_path}: {e}")
        return None


    

if key in vehicle_data and 'img' in vehicle_data[key]:
    print(vehicle_data[key])
    image_path = vehicle_data[key]['img']
    original_img = load_image(image_path)
    if original_img is not None:
        print("Original Image:")
        display(original_img)
else:
    print("No data Found")
# Out:
# {'Name': 'Rajesh Gupta', 'Address': '45, Park Street, Kolkata, West Bengal', 'State': 'West Bengal', 'Vehicle': 'Maruti Swift', 'img': 'C:\\Users\\Rana Yuvi\\OneDrive\\Desktop\\CGIP_miniproject\\pics\\WhatsApp Image 2024-07-26 at 01.20.18_6e942c19.jpg'}
# Original Image:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
# Out:
# {'img': 'C:\\Users\\Rana Yuvi\\OneDrive\\Desktop\\CGIP_miniproject\\pics\\WhatsApp Image 2024-07-26 at 01.20.18_6e942c19.jpg', 'Name': 'Rajesh Gupta', 'Address': '45, Park Street, Kolkata, West Bengal', 'State': 'West Bengal', 'Vehicle': 'Maruti Swift'}

# %%
cord = output[-1][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 cord = output[0]
#
# IndexError: string index out of range

# %%
cord
# Out:
# [[83, 51], [491, 51], [491, 137], [83, 137]]

# %%
a = list(zip(*cord))
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a = list(zip(*cord))
#       2 a
#
# NameError: name 'cord' is not defined

# %%
min(a[0])
# Out:
# 83

# %%
min(a[1])
# Out:
# 51

# %%
x_min, y_min = [int(min(idx)) for idx in zip(*cord)]

# %%
x_min, y_min
# Out:
# (83, 51)

# %%
x_max, y_max = [int(max(idx)) for idx in zip(*cord)]

# %%
x_max, y_max
# Out:
# (491, 137)

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 20, 30

# %%
image = cv2.imread(r'C:\Users\Rana Yuvi\OneDrive\Desktop\CGIP_miniproject\plates\scanned_img_0.jpg')
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
